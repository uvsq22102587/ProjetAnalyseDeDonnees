# %%
import pandas as pd
import numpy as np
import re as re

# %% [markdown]
# Lecture de données JSON

# %%
pdTweet = pd.read_json(path_or_buf="versailles_tweets_100.json")
pdTweet["text"][1]
# Out:
# '@ericbailly24 @maxigr04del  mes tontons vous avez fait votre part , JO prochain on ira en demi final au moins. BRAVO à vous . #SupportriceMazo #domie #CIV'

# %%
pdTweet
# Out:
#                     _id                                     public_metrics  \
# 0   1421616335700824064  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1   1421599703116943360  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2   1421599163561742336  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 3   1421591889095057408  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 4   1421582795294617600  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 5   1421581383454052352  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 6   1421575939700445184  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 7   1421569996858269696  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 8   1421563798503272448  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 9   1421562928176803840  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 10  1421560592775761920  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...

# %% [markdown]
# Extraction des tweet sans emoticônes (Expressions régulières)
# lien : https://stackoverflow.com/questions/33404752/removing-emojis-from-a-string-in-python

# %%
regex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)

# %% [markdown]
# retirer mention du texte d'un tweet

# %%
patern = re.compile("@[A-Za-z0-9]*")
print(patern.sub(r"",pdTweet["text"][1]))
# Out:
#    mes tontons vous avez fait votre part , JO prochain on ira en demi final au moins. BRAVO à vous . #SupportriceMazo #domie #CIV

# %% [markdown]
# retirer les hastags d'un tweet

# %%
patern = re.compile("#[A-Za-z0-9]*")
print(patern.sub(r"", pdTweet["text"][1]))
# Out:
# @ericbailly24 @maxigr04del  mes tontons vous avez fait votre part , JO prochain on ira en demi final au moins. BRAVO à vous .

# %%
pdTweetFiltre = pd.DataFrame(columns=["Auteur", "Texte", "Hashtag", "Mentions", "URL"])
pdTweetFiltre["Auteur"] = pdTweet["author_id"]

# %%
pdTweetFiltre["Texte"] = patern.sub(r"", pdTweet["Text"])
# Out:
#                  Auteur Texte Hashtag Mentions
# 0   1339914264522461184   NaN    None      NaN
# 1   1339914264522461184   NaN    None      NaN
# 2   1339914264522461184   NaN    None      NaN
# 3   1339914264522461184   NaN    None      NaN
# 4             717025418   NaN    None      NaN
# 5    992904738516717568   NaN    None      NaN
# 6    992904738516717568   NaN    None      NaN
# 7             736523371   NaN    None      NaN
# 8            1471684208   NaN    None      NaN
# 9    992904738516717568   NaN    None      NaN
# 10           3169236915   NaN    None      NaN
# 11   992904738516717568   NaN    None      NaN
# 12             16267684   NaN    None      NaN
# 13             60117154   NaN    None      NaN
# 14           3169236915   NaN    None      NaN
# 15            372993152   NaN    None      NaN
# 16            372993152   NaN    None      NaN
# 17            105241852   NaN    None      NaN
# 18           2357913366   NaN    None      NaN
# ...

# %% [markdown]
# Extraction Hashtags

# %%
# Crée un dataFrame avec les données inscrites dans entites, en columns on a Url, Mentions et Hashtags
pdDataFrameEntities = pdTweet["entities"].apply(pd.Series)
# Isole uniquement les hashatags en créeant un autre dataFrame
pdDataFrameHashtags = pdDataFrameEntities["hashtags"].apply(pd.Series)
# On a maintenant dans la variable pdDataFrameHashtags les hashtags des tweets, en columns le premier cité puis le deuxième etc.
pdDataFrameHashtags
# Out:
#                                                     0  \
# 0       {'start': 52, 'end': 63, 'tag': 'twitter225'}
# 1   {'start': 126, 'end': 142, 'tag': 'Supportrice...
# 2              {'start': 37, 'end': 41, 'tag': 'CIV'}
# 3             {'start': 60, 'end': 65, 'tag': 'jifa'}
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8       {'start': 20, 'end': 31, 'tag': 'versailles'}
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...
