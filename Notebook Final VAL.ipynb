# %%
import pandas as pd
import numpy as np
import re as re
import textblob as tb
from deep_translator import GoogleTranslator

# %% [markdown]
# Lecture de données JSON

# %%
pdTweet = pd.read_json(path_or_buf="versailles_tweets_100.json")
pdTweet
# Out:
#                     _id                                     public_metrics  \
# 0   1421616335700824064  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1   1421599703116943360  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2   1421599163561742336  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 3   1421591889095057408  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 4   1421582795294617600  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 5   1421581383454052352  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 6   1421575939700445184  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 7   1421569996858269696  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 8   1421563798503272448  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 9   1421562928176803840  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 10  1421560592775761920  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 11  1421558089761935360  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 12  1421551384512585728  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 13  1421550148061212672  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 14  1421547651171078144  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 15  1421499497620836352  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 16  1421499329974579200  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 17  1421487092023050240  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 18  1421472953980571648  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 19  1421429486432686080  {'retweet_count': 2, 'reply_count': 1, 'like_c...
#
#                      id      conversation_id            author_id  \
# 0   1421616335700824064  1421616335700824064  1339914264522461184
# 1   1421599703116943360  1421599703116943360  1339914264522461184
# 2   1421599163561742336  1421599163561742336  1339914264522461184
# 3   1421591889095057408  1421591889095057408  1339914264522461184
# 4   1421582795294617600  1421582795294617600            717025418
# 5   1421581383454052352  1421256177359466496   992904738516717568
# 6   1421575939700445184  1421256177359466496   992904738516717568
# 7   1421569996858269696  1421569996858269696            736523371
# 8   1421563798503272448  1421563798503272448           1471684208
# 9   1421562928176803840  1421553997811421184   992904738516717568
# 10  1421560592775761920  1421527117720866816           3169236915
# 11  1421558089761935360  1421231846814330880   992904738516717568
# 12  1421551384512585728  1421551384512585728             16267684
# 13  1421550148061212672  1421550148061212672             60117154
# 14  1421547651171078144  1421516307393044480           3169236915
# 15  1421499497620836352  1421499497620836352            372993152
# 16  1421499329974579200  1421165014254301184            372993152
# 17  1421487092023050240  1421487092023050240            105241852
# 18  1421472953980571648  1421384380841353216           2357913366
# 19  1421429486432686080  1421429486432686080            717025418
#
#                                                  text  \
# 0   Goumin des éléphants joueurs la même fatigue m...
# 1   @ericbailly24 @maxigr04del  mes tontons vous a...
# 2   Ah oui le sommeil là sera compliqué. #CIV  est...
# 3   31 juillet , journée internationale de la femm...
# 4            Le pedigree 😂😂😂😂 https://t.co/D3Rv7A2BOF
# 5   @isabelle170516 @leonna_julie @Steiner2502 Vou...
# 6   @LynLyna12 @leonna_julie La grande muette cont...
# 7                                       Under wsh 😳😳😳
# 8   Les bains d'apollon #versailles #nocturne #app...
# 9   @leonna_julie Le rdv aujourd'hui aura  tenu se...
# 10  @miliemelo82 @kilianbridoux @LeMeneec il est t...
# 11  @Polo82810715 @lrestistant73 Un mouton c'est  ...
# 12  I'm at Gardens of Versailles in Versailles, Îl...
# 13  Jungle Cruise https://t.co/JyM8WQjz4p (@ UGC C...
# 14                                  @Pauluskupa 🤦🏼‍♀️
# 15                          @anniemacmanus legend!!!!
# 16                       @yebbasmith @anniemacmanus 😍
# 17  Vient de publier une photo à Quelquepart ... h...
# 18        @AzmiAnees3 He was my lover’s accomplice😂🤣🤣
# 19  Le gardien lui parle non ? https://t.co/e3WewD...
#
#                                                   geo lang  \
# 0                    {'place_id': '00b8943291443c8c'}   fr
# 1                    {'place_id': '00b8943291443c8c'}   fr
# 2                    {'place_id': '00b8943291443c8c'}   fr
# 3                    {'place_id': '00b8943291443c8c'}   fr
# 4                    {'place_id': '00b8943291443c8c'}   es
# 5                    {'place_id': '011a304d683c2461'}   fr
# 6                    {'place_id': '011a304d683c2461'}   fr
# 7                    {'place_id': '011a304d683c2461'}   en
# 8   {'place_id': '011a304d683c2461', 'coordinates'...   fr
# 9                    {'place_id': '011a304d683c2461'}   fr
# 10                   {'place_id': '011a304d683c2461'}   fr
# 11                   {'place_id': '011a304d683c2461'}   fr
# 12  {'place_id': '011a304d683c2461', 'coordinates'...   fr
# 13  {'place_id': '011a304d683c2461', 'coordinates'...   fr
# 14                   {'place_id': '011a304d683c2461'}  und
# 15                   {'place_id': '011a304d683c2461'}   en
# 16                   {'place_id': '011a304d683c2461'}  und
# 17  {'place_id': '00b8943291443c8c', 'coordinates'...   fr
# 18                   {'place_id': '011a304d683c2461'}   en
# 19                   {'place_id': '00b8943291443c8c'}   fr
#
#                   created_at  \
# 0  2021-07-31 23:38:41+00:00
# 1  2021-07-31 22:32:35+00:00
# 2  2021-07-31 22:30:27+00:00
# 3  2021-07-31 22:01:32+00:00
# 4  2021-07-31 21:25:24+00:00
# 5  2021-07-31 21:19:48+00:00
# 6  2021-07-31 20:58:10+00:00
# 7  2021-07-31 20:34:33+00:00
# 8  2021-07-31 20:09:55+00:00
# 9  2021-07-31 20:06:28+00:00
# 10 2021-07-31 19:57:11+00:00
# 11 2021-07-31 19:47:14+00:00
# 12 2021-07-31 19:20:35+00:00
# 13 2021-07-31 19:15:41+00:00
# 14 2021-07-31 19:05:45+00:00
# 15 2021-07-31 15:54:25+00:00
# 16 2021-07-31 15:53:45+00:00
# 17 2021-07-31 15:05:07+00:00
# 18 2021-07-31 14:08:56+00:00
# 19 2021-07-31 11:16:13+00:00
#
#                                              entities  \
# 0   {'hashtags': [{'start': 52, 'end': 63, 'tag': ...
# 1   {'mentions': [{'start': 0, 'end': 13, 'usernam...
# 2   {'hashtags': [{'start': 37, 'end': 41, 'tag': ...
# 3   {'hashtags': [{'start': 60, 'end': 65, 'tag': ...
# 4   {'urls': [{'start': 17, 'end': 40, 'url': 'htt...
# 5   {'mentions': [{'start': 0, 'end': 15, 'usernam...
# 6   {'mentions': [{'start': 0, 'end': 10, 'usernam...
# 7                                                 NaN
# 8   {'urls': [{'start': 76, 'end': 99, 'url': 'htt...
# 9   {'mentions': [{'start': 0, 'end': 13, 'usernam...
# 10  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 11  {'mentions': [{'start': 0, 'end': 13, 'usernam...
# 12  {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 13  {'urls': [{'start': 14, 'end': 37, 'url': 'htt...
# 14  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 15  {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 16  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 17  {'urls': [{'start': 45, 'end': 68, 'url': 'htt...
# 18  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 19  {'urls': [{'start': 27, 'end': 50, 'url': 'htt...
#
#                                   context_annotations  \
# 0                                                 NaN
# 1   [{'domain': {'id': '6', 'name': 'Sports Event'...
# 2   [{'domain': {'id': '6', 'name': 'Sports Event'...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  [{'domain': {'id': '86', 'name': 'Movie', 'des...
# 14                                                NaN
# 15  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 16  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                   attachments
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9   {'media_keys': ['3_1421562925999869960']}
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN

# %% [markdown]
# <H3> Partie nettoyage du texte <H3/>

# %% [markdown]
# Retire les retours à la ligne:

# %%
def no_retourchariot(chiffre):
    """Fonction qui retire les retours à la ligne du texte"""
    patern = re.compile("\n")
    result = patern.sub(r"",pdTweet["text"][chiffre])
    return result

# %% [markdown]
# Extraction des tweet sans emoticônes (Expressions régulières)
#
#
# Source: https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b?permalink_comment_id=3315605#gistcomment-3315605

# %%
def no_emoticone(chiffre):
        """fonction qui retire tout les émoticones du tweet"""
        patern  = re.compile("["
                        u"\U0001F600-\U0001F64F"  # emoticons
                        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                        u"\U0001F680-\U0001F6FF"  # transport & map symbols
                        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                        u"\U00002500-\U00002BEF"  # chinese char
                        u"\U00002702-\U000027B0"
                        u"\U00002702-\U000027B0"
                        u"\U000024C2-\U0001F251"
                        u"\U0001f926-\U0001f937"
                        u"\U00010000-\U0010ffff"
                        u"\u2640-\u2642"
                        u"\u2600-\u2B55"
                        u"\u200d"
                        u"\u23cf"
                        u"\u23e9"
                        u"\u231a"
                        u"\ufe0f"  # dingbats
                        u"\u3030"
                                "]+", flags = re.UNICODE)
        
        result = patern.sub(r"",chiffre)
        return result

# %% [markdown]
# Retire mention du texte d'un tweet

# %%
def no_mention(chiffre):
    """Fonction qui retire les mentions du tweet"""
    patern = re.compile("@\S*")
    result = patern.sub(r"",chiffre)
    return result

# %% [markdown]
# Retire les hastags d'un tweet

# %%
def no_hastags(chiffre):
    """fonction qui retire les hastags du tweet"""
    patern = re.compile("#\S*")
    result = patern.sub(r"",chiffre)
    return result

# %% [markdown]
# Retire l'intégration d'un URL dans un tweet

# %%
def no_URL(chiffre):
    """fonction qui retire l'URL d'un tweet"""
    patern = re.compile("https://\S*")
    result = patern.sub(r"", chiffre)
    return result

# %% [markdown]
# Fonction qui nettoie le texte avec toutes les fonctions créé auparavant.

# %%
def menage(NumeroTweet):
    "fonction qui applique toutes les autres fonction pour avoir un texte propre"
    result = no_retourchariot(NumeroTweet)
    result = no_emoticone(result)
    result = no_mention(result)
    result = no_hastags(result)
    result = no_URL(result)
    return result

# %%
pdTweetFiltre = pd.DataFrame()

# %% [markdown]
# Insérer le texte nettoyer des tweet dans le data Frame TweetFiltrer

# %%
#insertion du texte nettoyer dans le Data Frame TweetFiltrer
list_texte = []
for i in range(0,20):
    texte = menage(i)
    list_texte.append(texte)
pdTweetFiltre["Texte"] = list_texte
pdTweetFiltre
# Out:
#                                                 Texte
# 0   Goumin des éléphants joueurs la même fatigue m...
# 1      mes tontons vous avez fait votre part , JO ...
# 2   Ah oui le sommeil là sera compliqué.   est éli...
# 3   31 juillet , journée internationale de la femm...
# 4                                       Le pedigree
# 5      Vous avez tt à fait raison! le silence inco...
# 6     La grande muette continue et continuera de l...
# 7                                          Under wsh
# 8     Les bains d'apollon    à Château de Versailles
# 9    Le rdv aujourd'hui aura  tenu ses promesses! ...
# 10                    il est temps de laisser mijoter
# 11    Un mouton c'est  bien plus intelligent que t...
# 12  I'm at Gardens of Versailles in Versailles, Îl...
# 13  Jungle Cruise  ( UGC Cyrano in Versailles, Île...
# 14
# 15                                         legend!!!!
# 16
# 17      Vient de publier une photo à Quelquepart ...
# 18                       He was my lover’s accomplice
# 19                        Le gardien lui parle non ?

# %% [markdown]
# <H3>Partie gestion Mentions URl et Hashtags<H3/>

# %%
# Crée un dataFrame avec les données inscrites dans entites, en columns on a Url, Mentions et Hashtags
pdEntities = pdTweet["entities"].apply(pd.Series)
# On supprime la column 0 qui ne contient rien.
del pdEntities[0]
pdEntities
# Out:
#                                              hashtags  \
# 0     [{'start': 52, 'end': 63, 'tag': 'twitter225'}]
# 1   [{'start': 126, 'end': 142, 'tag': 'Supportric...
# 2            [{'start': 37, 'end': 41, 'tag': 'CIV'}]
# 3           [{'start': 60, 'end': 65, 'tag': 'jifa'}]
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   [{'start': 20, 'end': 31, 'tag': 'versailles'}...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                              mentions  \
# 0                                                 NaN
# 1   [{'start': 0, 'end': 13, 'username': 'ericbail...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   [{'start': 0, 'end': 15, 'username': 'isabelle...
# 6   [{'start': 0, 'end': 10, 'username': 'LynLyna1...
# 7                                                 NaN
# 8                                                 NaN
# 9   [{'start': 0, 'end': 13, 'username': 'leonna_j...
# 10  [{'start': 0, 'end': 12, 'username': 'miliemel...
# 11  [{'start': 0, 'end': 13, 'username': 'Polo8281...
# 12                                                NaN
# 13                                                NaN
# 14  [{'start': 0, 'end': 11, 'username': 'Paulusku...
# 15  [{'start': 0, 'end': 14, 'username': 'anniemac...
# 16  [{'start': 0, 'end': 11, 'username': 'yebbasmi...
# 17                                                NaN
# 18  [{'start': 0, 'end': 11, 'username': 'AzmiAnee...
# 19                                                NaN
#
#                                                  urls
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [{'start': 17, 'end': 40, 'url': 'https://t.co...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   [{'start': 76, 'end': 99, 'url': 'https://t.co...
# 9   [{'start': 279, 'end': 302, 'url': 'https://t....
# 10                                                NaN
# 11                                                NaN
# 12  [{'start': 58, 'end': 81, 'url': 'https://t.co...
# 13  [{'start': 14, 'end': 37, 'url': 'https://t.co...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  [{'start': 45, 'end': 68, 'url': 'https://t.co...
# 18                                                NaN
# 19  [{'start': 27, 'end': 50, 'url': 'https://t.co...

# %% [markdown]
# Cette cellule trie les informations stockées dans la colonnes "Entities" dans le dataframe initial et le stocke dans un autre dataframe.

# %%
for columns_name in pdEntities:
        lenSeries = len(pdEntities[columns_name])
        lElement = []
        if columns_name == "hashtags":
                key = "tag"
        elif columns_name == "mentions":
                key = "username"
        elif columns_name == "urls":
                key = "url"
        else:
                key = None
        for i in range(0,lenSeries):
                lElementUnder = []
                if type(pdEntities[columns_name][i]) == list:
                        for j in range(0, int(len(pdEntities[columns_name][i]))):
                                lElementUnder.append(pdEntities[columns_name][i][j].get(key))
                else:
                        lElementUnder.append(None)
                lElement.append(lElementUnder)
        lElement = pd.Series(lElement)
        pdTweetFiltre[columns_name] = lElement
pdTweetFiltre
# Out:
#                                                 Texte  \
# 0   Goumin des éléphants joueurs la même fatigue m...
# 1      mes tontons vous avez fait votre part , JO ...
# 2   Ah oui le sommeil là sera compliqué.   est éli...
# 3   31 juillet , journée internationale de la femm...
# 4                                       Le pedigree
# 5      Vous avez tt à fait raison! le silence inco...
# 6     La grande muette continue et continuera de l...
# 7                                          Under wsh
# 8     Les bains d'apollon    à Château de Versailles
# 9    Le rdv aujourd'hui aura  tenu ses promesses! ...
# 10                    il est temps de laisser mijoter
# 11    Un mouton c'est  bien plus intelligent que t...
# 12  I'm at Gardens of Versailles in Versailles, Îl...
# 13  Jungle Cruise  ( UGC Cyrano in Versailles, Île...
# 14
# 15                                         legend!!!!
# 16
# 17      Vient de publier une photo à Quelquepart ...
# 18                       He was my lover’s accomplice
# 19                        Le gardien lui parle non ?
#
#                             hashtags  \
# 0                       [twitter225]
# 1      [SupportriceMazo, domie, CIV]
# 2                              [CIV]
# 3                             [jifa]
# 4                             [None]
# 5                             [None]
# 6                             [None]
# 7                             [None]
# 8   [versailles, nocturne, appollon]
# 9                             [None]
# 10                            [None]
# 11                            [None]
# 12                            [None]
# 13                            [None]
# 14                            [None]
# 15                            [None]
# 16                            [None]
# 17                            [None]
# 18                            [None]
# 19                            [None]
#
#                                        mentions  \
# 0                                        [None]
# 1                   [ericbailly24, maxigr04del]
# 2                                        [None]
# 3                                        [None]
# 4                                        [None]
# 5   [isabelle170516, leonna_julie, Steiner2502]
# 6                     [LynLyna12, leonna_julie]
# 7                                        [None]
# 8                                        [None]
# 9                                [leonna_julie]
# 10       [miliemelo82, kilianbridoux, LeMeneec]
# 11                [Polo82810715, lrestistant73]
# 12                                       [None]
# 13                                       [None]
# 14                                 [Pauluskupa]
# 15                              [anniemacmanus]
# 16                  [yebbasmith, anniemacmanus]
# 17                                       [None]
# 18                                 [AzmiAnees3]
# 19                                       [None]
#
#                                                  urls
# 0                                              [None]
# 1                                              [None]
# 2                                              [None]
# 3                                              [None]
# 4                           [https://t.co/D3Rv7A2BOF]
# 5                                              [None]
# 6                                              [None]
# 7                                              [None]
# 8                           [https://t.co/SFGXP06r61]
# 9                           [https://t.co/F6zvVfWwAf]
# 10                                             [None]
# 11                                             [None]
# 12                          [https://t.co/fG7Q40cjWk]
# 13  [https://t.co/JyM8WQjz4p, https://t.co/ts0FrwW...
# 14                                             [None]
# 15                                             [None]
# 16                                             [None]
# 17                          [https://t.co/fWNqGJosAA]
# 18                                             [None]
# 19                          [https://t.co/e3WewDSQOJ]

# %% [markdown]
# On rajoute les id des auteurs dans le dataframe

# %%
pdTweetFiltre["author"] = pdTweet["author_id"]
pdTweetFiltre
# Out:
#                                                 Texte  \
# 0   Goumin des éléphants joueurs la même fatigue m...
# 1      mes tontons vous avez fait votre part , JO ...
# 2   Ah oui le sommeil là sera compliqué.   est éli...
# 3   31 juillet , journée internationale de la femm...
# 4                                       Le pedigree
# 5      Vous avez tt à fait raison! le silence inco...
# 6     La grande muette continue et continuera de l...
# 7                                          Under wsh
# 8     Les bains d'apollon    à Château de Versailles
# 9    Le rdv aujourd'hui aura  tenu ses promesses! ...
# 10                    il est temps de laisser mijoter
# 11    Un mouton c'est  bien plus intelligent que t...
# 12  I'm at Gardens of Versailles in Versailles, Îl...
# 13  Jungle Cruise  ( UGC Cyrano in Versailles, Île...
# 14
# 15                                         legend!!!!
# 16
# 17      Vient de publier une photo à Quelquepart ...
# 18                       He was my lover’s accomplice
# 19                        Le gardien lui parle non ?
#
#                             hashtags  \
# 0                       [twitter225]
# 1      [SupportriceMazo, domie, CIV]
# 2                              [CIV]
# 3                             [jifa]
# 4                             [None]
# 5                             [None]
# 6                             [None]
# 7                             [None]
# 8   [versailles, nocturne, appollon]
# 9                             [None]
# 10                            [None]
# 11                            [None]
# 12                            [None]
# 13                            [None]
# 14                            [None]
# 15                            [None]
# 16                            [None]
# 17                            [None]
# 18                            [None]
# 19                            [None]
#
#                                        mentions  \
# 0                                        [None]
# 1                   [ericbailly24, maxigr04del]
# 2                                        [None]
# 3                                        [None]
# 4                                        [None]
# 5   [isabelle170516, leonna_julie, Steiner2502]
# 6                     [LynLyna12, leonna_julie]
# 7                                        [None]
# 8                                        [None]
# 9                                [leonna_julie]
# 10       [miliemelo82, kilianbridoux, LeMeneec]
# 11                [Polo82810715, lrestistant73]
# 12                                       [None]
# 13                                       [None]
# 14                                 [Pauluskupa]
# 15                              [anniemacmanus]
# 16                  [yebbasmith, anniemacmanus]
# 17                                       [None]
# 18                                 [AzmiAnees3]
# 19                                       [None]
#
#                                                  urls               author
# 0                                              [None]  1339914264522461184
# 1                                              [None]  1339914264522461184
# 2                                              [None]  1339914264522461184
# 3                                              [None]  1339914264522461184
# 4                           [https://t.co/D3Rv7A2BOF]            717025418
# 5                                              [None]   992904738516717568
# 6                                              [None]   992904738516717568
# 7                                              [None]            736523371
# 8                           [https://t.co/SFGXP06r61]           1471684208
# 9                           [https://t.co/F6zvVfWwAf]   992904738516717568
# 10                                             [None]           3169236915
# 11                                             [None]   992904738516717568
# 12                          [https://t.co/fG7Q40cjWk]             16267684
# 13  [https://t.co/JyM8WQjz4p, https://t.co/ts0FrwW...             60117154
# 14                                             [None]           3169236915
# 15                                             [None]            372993152
# 16                                             [None]            372993152
# 17                          [https://t.co/fWNqGJosAA]            105241852
# 18                                             [None]           2357913366
# 19                          [https://t.co/e3WewDSQOJ]            717025418

# %% [markdown]
# On fait les mêmes manipulations pour les topics.
# (A détailler encore parce que c'est pas exactement les mêmes manipulations.)

# %%
sTopics = []
for ligne in pdTweet["context_annotations"]:
    sTopicsTweet = []
    if type(ligne) == list:
        lenSeries = len(ligne)
        for i in range(0, lenSeries):
            topics = ligne[i].get("domain").get("name")
            if topics not in sTopicsTweet:
                sTopicsTweet.append(topics)
    else:
        sTopicsTweet.append(None)
    sTopics.append(sTopicsTweet)
pdTweetFiltre["topics"] = sTopics
pdTweetFiltre
# Out:
#                                                 Texte  \
# 0   Goumin des éléphants joueurs la même fatigue m...
# 1      mes tontons vous avez fait votre part , JO ...
# 2   Ah oui le sommeil là sera compliqué.   est éli...
# 3   31 juillet , journée internationale de la femm...
# 4                                       Le pedigree
# 5      Vous avez tt à fait raison! le silence inco...
# 6     La grande muette continue et continuera de l...
# 7                                          Under wsh
# 8     Les bains d'apollon    à Château de Versailles
# 9    Le rdv aujourd'hui aura  tenu ses promesses! ...
# 10                    il est temps de laisser mijoter
# 11    Un mouton c'est  bien plus intelligent que t...
# 12  I'm at Gardens of Versailles in Versailles, Îl...
# 13  Jungle Cruise  ( UGC Cyrano in Versailles, Île...
# 14
# 15                                         legend!!!!
# 16
# 17      Vient de publier une photo à Quelquepart ...
# 18                       He was my lover’s accomplice
# 19                        Le gardien lui parle non ?
#
#                             hashtags  \
# 0                       [twitter225]
# 1      [SupportriceMazo, domie, CIV]
# 2                              [CIV]
# 3                             [jifa]
# 4                             [None]
# 5                             [None]
# 6                             [None]
# 7                             [None]
# 8   [versailles, nocturne, appollon]
# 9                             [None]
# 10                            [None]
# 11                            [None]
# 12                            [None]
# 13                            [None]
# 14                            [None]
# 15                            [None]
# 16                            [None]
# 17                            [None]
# 18                            [None]
# 19                            [None]
#
#                                        mentions  \
# 0                                        [None]
# 1                   [ericbailly24, maxigr04del]
# 2                                        [None]
# 3                                        [None]
# 4                                        [None]
# 5   [isabelle170516, leonna_julie, Steiner2502]
# 6                     [LynLyna12, leonna_julie]
# 7                                        [None]
# 8                                        [None]
# 9                                [leonna_julie]
# 10       [miliemelo82, kilianbridoux, LeMeneec]
# 11                [Polo82810715, lrestistant73]
# 12                                       [None]
# 13                                       [None]
# 14                                 [Pauluskupa]
# 15                              [anniemacmanus]
# 16                  [yebbasmith, anniemacmanus]
# 17                                       [None]
# 18                                 [AzmiAnees3]
# 19                                       [None]
#
#                                                  urls               author  \
# 0                                              [None]  1339914264522461184
# 1                                              [None]  1339914264522461184
# 2                                              [None]  1339914264522461184
# 3                                              [None]  1339914264522461184
# 4                           [https://t.co/D3Rv7A2BOF]            717025418
# 5                                              [None]   992904738516717568
# 6                                              [None]   992904738516717568
# 7                                              [None]            736523371
# 8                           [https://t.co/SFGXP06r61]           1471684208
# 9                           [https://t.co/F6zvVfWwAf]   992904738516717568
# 10                                             [None]           3169236915
# 11                                             [None]   992904738516717568
# 12                          [https://t.co/fG7Q40cjWk]             16267684
# 13  [https://t.co/JyM8WQjz4p, https://t.co/ts0FrwW...             60117154
# 14                                             [None]           3169236915
# 15                                             [None]            372993152
# 16                                             [None]            372993152
# 17                          [https://t.co/fWNqGJosAA]            105241852
# 18                                             [None]           2357913366
# 19                          [https://t.co/e3WewDSQOJ]            717025418
#
#                              topics
# 0                            [None]
# 1   [Sports Event, Person, Athlete]
# 2                    [Sports Event]
# 3                            [None]
# 4                            [None]
# 5                            [None]
# 6                            [None]
# 7                            [None]
# 8                            [None]
# 9                            [None]
# 10                           [None]
# 11                           [None]
# 12                           [None]
# 13             [Movie, Movie Genre]
# 14                           [None]
# 15               [Person, Musician]
# 16  [Person, Musician, Music Genre]
# 17                           [None]
# 18                           [None]
# 19                           [None]

# %%
pdTweetFiltre.shape[0]
# Out:
# 20

# %% [markdown]
# Utilisation de la libraire textBlob pour donner le sentiment (négatif ou positif) du tweet
#  à partir de son texte.

# %%
def analysis_sentiment(source:pd.DataFrame):
    translator = GoogleTranslator(target="en")
    liste_sentiment = []
    for i in range(0, len(source["Texte"])):
        texte = source["Texte"][i]
        texte_Angl = translator.translate(texte)
        liste_sentiment.append(tb.TextBlob(texte_Angl).sentiment[0])
    return liste_sentiment

# %%
pdTweetFiltre["sentiment"] = analysis_sentiment(pdTweetFiltre)

# %% [markdown]
# <H4>Top K hashtags:</H4>
#
# On va lire dans le dataFrame qu'on a créé les différents hashtags présent.
# Pour chaque hashtags, si il est dans la liste des clés déja renseigné, on ajoute + 1 a la valeur de la clé. Sinon, on le rajoute dans la liste des clés et on l'initialise à 1.
#
# On va ensuite obtenir les valeurs les plus grandes du dictionnaire avec la fonction max. Si la valeur est représenté plusieurs fois (2ième exaquo) on montrera toutes les valeurs qui correpondent au maximum.

# %% [markdown]
# Les données sont organisées de la même manière pour les mentions et les url. On peut donc créer une fonction qui prend 3 arguments: k qui correspond le nombre de valeurs à afficher, source qui est le dataframe duquel on va afficher le classement et entities qui est une variable pour faire le choix entre mentions, hashtags et topics.

# %%
def extraire_dict(entities:str, source:pd.DataFrame):
    """
    Cette fonction permet d'extraire les donnnées du dataframe sous forme de dictionnaire.
    On peut utiliser dans "entities" les arguments: Hashtags, mentions, author et topics.
    Author est vu comme une exception car il n'est pas stocké de la même manière que les autres.
    """
    dict_Entities = {}
    series_Entities = source[entities]
    if entities == "author":
        dataFrame_Top = pd.DataFrame(series_Entities.value_counts())
        dict_Entities = dataFrame_Top.to_dict()["author"]
    else:
        for tweet in series_Entities:
            for i in range(0, len(tweet)):
                value = dict_Entities.get(tweet[i])
                # Value représente le nombre de fois que le hashtags a déjà été lu dans le DataFrame.
                # Si c'est la première fois qu'on le voit, value retourne None et donc on initialise à 1
                if value != None:
                    dict_Entities[tweet[i]] = value + 1
                else:
                    dict_Entities[tweet[i]] = 1
        # On supprime la colonne qui montre les tweets sans hashtags
        del dict_Entities[None]
    return dict_Entities

# %%
def top(k:int, source:pd.DataFrame, entities:str):
    """
    On prend dans source (qui doit être un data frame) le podium de l'entités demandé,
    L'entité peut être les hashtags, les utilisateurs, les topics ou encore les mentions.
    On réutilise la fonction créer avant pour obtenir le dictionnaire, puis on applique le trie
    pour afficher le top.
    """
    dict_Entities = extraire_dict(entities, source)
    dict_Top = {}
    # On veut le top k 
    for top in range(1, k + 1):
        if dict_Entities.values().__len__() != 0:
            dict_Top[top] = []
            maxRepresenter = max(dict_Entities.values())
            for key, values in dict_Entities.items():
                if values == maxRepresenter:
                    dict_Top[top].append(key)
            for candidat in dict_Top[top]:
                del dict_Entities[candidat]
    dataFrame_Top = pd.DataFrame()
    for top, hashtags in dict_Top.items():
        # Pour éviter les problèmes de tailles de colonnes, on va créer un df éphémère à chaque fois
        dfEphemere = pd.DataFrame()
        dfEphemere[top] = pd.Series(hashtags)
        # Puis on va le joindre à l'ancien df.
        dataFrame_Top = pd.concat([dataFrame_Top, dfEphemere], join="outer", axis=1)
    return dataFrame_Top

# %%
top(3, pdTweetFiltre, "hashtags")
# Out:
#      1                2
# 0  CIV       twitter225
# 1  NaN  SupportriceMazo
# 2  NaN            domie
# 3  NaN             jifa
# 4  NaN       versailles
# 5  NaN         nocturne
# 6  NaN         appollon

# %% [markdown]
# Pour obtenir le nombre de publication d'un utilisateur, le nombre de publications qui comporte un hashtags en particulier ou encore le nombre de publication par topics, on prend la fonction qui permet de nous donner un dictionnaire et on cherche dans ce dictionnaire la clé qu'il nous intéresse.

# %%
def nbr_publi(name, source:pd.DataFrame, domaine:str):
    """
    Fonction qui retourne le nombre de publication dans un domaine. Le domain peut-être soit author, soit hashtags, soit mentions.
    La variable name définit soit l'id de l'utilisateur, soit le hashtags soit le nom du topic dans le cas d'une recherche 
    par topics.
    """
    return extraire_dict(domaine, source).get(name)

# %%
nbr_publi("CIV", pdTweetFiltre, domaine="hashtags")
# Out:
# 2
